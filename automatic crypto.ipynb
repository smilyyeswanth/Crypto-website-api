# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11818
# 1    1027     Ethereum    ETH      ethereum              9625
# 2      52          XRP    XRP           xrp              1460
# 3     825  Tether USDt   USDT        tether            106569
# 4    5426       Solana    SOL        solana               802
# 5    1839          BNB    BNB           bnb              2293
# 6      74     Dogecoin   DOGE      dogecoin              1116
# 7    2010      Cardano    ADA       cardano              1380
# 8    3408         USDC   USDC      usd-coin             23538
# 9    1958         TRON    TRX          tron              1079
# 10   5805    Avalanche   AVAX     avalanche               814
# 11   5994    Shiba Inu   SHIB     shiba-inu               913
# 12  11419      Toncoin    TON       toncoin               628
# 13    512      Stellar    XLM       stellar               642
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)


        # Assuming this code is part of a larger function or block
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')  # Add a timestamp column

# Append df2 to df using pd.concat
    df = pd.concat([df, df2], ignore_index=True)


#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
    
    # Use this if you just want to keep it in a dataframe
    # Normalize and process the data
      

    # Use this if you want to create a csv and append data to it
    #df = pd.json_normalize(data['data'])
    #df['timestamp'] = pd.to_datetime('now')
    #df

    if not os.path.isfile('/Users/yeswanthkambakkam/Documents/python/API.csv'):
        df.to_csv('/Users/yeswanthkambakkam/Documents/python/API.csv', header='column_names')
    else:
        df.to_csv('/Users/yeswanthkambakkam/Documents/python/API.csv', mode='a', header=False)
        
    #Then to read in the file:
        df = pd.read_csv('/Users/yeswanthkambakkam/Documents/python/API.csv')

# If that didn't work try using the local host URL as shown in the video

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    # Assuming 'data' is obtained earlier in the code
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')

    # Append df2 to df using pd.concat
    df = pd.concat([df, df2], ignore_index=True)

    print("API Runner completed")
    sleep(60)  # Sleep for 1 minute
# Out:
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      11 df = pd.concat([df, df2], ignore_index=True)
#      13 print("API Runner completed")
# ---> 14 sleep(60)
#
# KeyboardInterrupt:

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11818
# 1    1027     Ethereum    ETH      ethereum              9625
# 2      52          XRP    XRP           xrp              1460
# 3     825  Tether USDt   USDT        tether            106569
# 4    5426       Solana    SOL        solana               802
# 5    1839          BNB    BNB           bnb              2293
# 6      74     Dogecoin   DOGE      dogecoin              1116
# 7    2010      Cardano    ADA       cardano              1380
# 8    3408         USDC   USDC      usd-coin             23538
# 9    1958         TRON    TRX          tron              1079
# 10   5805    Avalanche   AVAX     avalanche               814
# 11   5994    Shiba Inu   SHIB     shiba-inu               913
# 12  11419      Toncoin    TON       toncoin               628
# 13    512      Stellar    XLM       stellar               642
# ...

# %%
import os
print(os.listdir('/Users/yeswanthkambakkam/'))
# Out:
# ['iris.names', 'iris1.csv', '.config', 'Music', 'all.ipynb', 'customers.csv', '.condarc', 'Netflix_Dataset.csv', '.docker', 'Untitled5.ipynb', 'Untitled1.ipynb', 'big.ipynb', 'Movie correlation project.ipynb', 'groupbypandas .ipynb', '.DS_Store', 'VirtualBox VMs', '.CFUserTextEncoding', '.xonshrc', 'men_results.csv', 'Untitled.ipynb', '.zshrc', 'OneDrive', '.psql_history', 'matplotlib.ipynb', 'Untitled6.ipynb', 'projects', 'Pictures', 'notebook.ipynb', '.zprofile', 'Amazon Web Scraper Project.ipynb', 'hypothesis testing.ipynb', '.zsh_history', '.ipython', 'Desktop', 'Library', '.matplotlib', 'tips.csv', 'Pandas_tutorial.ipynb', '.lesshst', 'dist-gem5', 'zoo.csv', 'AIassignment1.ipynb', 'scikit.ipynb', 'NumPy_exercise.ipynb', 'RIDA1.ipynb', '.android', '.pgadmin', 'scikit_learn_data', 'Sites', 'minepython.ipynb', 'oops.ipynb', 'file.csv', 'files.csv', 'automatic crypto.ipynb', 'PRassignment2.ipynb', 'Customer Analytics.ipynb', 'PycharmProjects', 'Public', 'AI_assignment1.ipynb', 'wine
# ...

# %%
#df72 = pd.read_csv('/Users/yeswanthkambakkam/API.csv')
#df72

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11818
# 1    1027     Ethereum    ETH      ethereum              9625
# 2      52          XRP    XRP           xrp              1460
# 3     825  Tether USDt   USDT        tether            106569
# 4    5426       Solana    SOL        solana               802
# 5    1839          BNB    BNB           bnb              2293
# 6      74     Dogecoin   DOGE      dogecoin              1116
# 7    2010      Cardano    ADA       cardano              1380
# 8    3408         USDC   USDC      usd-coin             23538
# 9    1958         TRON    TRX          tron              1079
# 10   5805    Avalanche   AVAX     avalanche               814
# 11   5994    Shiba Inu   SHIB     shiba-inu               913
# 12  11419      Toncoin    TON       toncoin               628
# 13    512      Stellar    XLM       stellar               642
# ...

# %%
# Now let's look at the coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.08304                      -0.07343
# Ethereum                         0.02428                       0.47544
# XRP                              0.10145                      -5.81362
# Tether USDt                     -0.02125                       0.04075
# Solana                          -1.23258                       4.09043
# BNB                             -1.90001                      14.97774
# Dogecoin                        -0.66279                      -1.84070
# Cardano                         -0.12807                      -5.23153
# USDC                            -0.01004                      -0.00245
# TRON                             0.81213                      70.30724
# Avalanche                       -0.39707                       0.30836
# Shiba Inu                       -0.41743                       2.33843
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.08304
#              quote.USD.percent_change_24h    -0.07343
#              quote.USD.percent_change_7d      3.37981
#              quote.USD.percent_change_30d    38.63855
#              quote.USD.percent_change_60d    55.25072
#              quote.USD.percent_change_90d    67.55011
# Ethereum     quote.USD.percent_change_1h      0.02428
#              quote.USD.percent_change_24h     0.47544
#              quote.USD.percent_change_7d      9.09595
#              quote.USD.percent_change_30d    47.75395
#              quote.USD.percent_change_60d    52.94390
#              quote.USD.percent_change_90d    51.25347
# XRP          quote.USD.percent_change_1h      0.10145
#              quote.USD.percent_change_24h    -5.81362
#              quote.USD.percent_change_7d     85.54556
#              quote.USD.percent_change_30d   402.97861
#              quote.USD.percent_change_60d   382.67372
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.08304
#             quote.USD.percent_change_24h  -0.07343
#             quote.USD.percent_change_7d    3.37981
#             quote.USD.percent_change_30d  38.63855
#             quote.USD.percent_change_60d  55.25072
#             quote.USD.percent_change_90d  67.55011
# Ethereum    quote.USD.percent_change_1h    0.02428
#             quote.USD.percent_change_24h   0.47544
#             quote.USD.percent_change_7d    9.09595
#             quote.USD.percent_change_30d  47.75395
#             quote.USD.percent_change_60d  52.94390
#             quote.USD.percent_change_90d  51.25347
# XRP         quote.USD.percent_change_1h    0.10145
#             quote.USD.percent_change_24h  -5.81362
#             quote.USD.percent_change_7d   85.54556
#             quote.USD.percent_change_30d 402.97861
#             quote.USD.percent_change_60d 382.67372
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. You can make this more dynamic, but I'm just going to hard code it


index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.set_index(index)
df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"
# Out:
#       values
# 0   -0.08304
# 1   -0.07343
# 2    3.37981
# 3   38.63855
# 4   55.25072
# 5   67.55011
# 6    0.02428
# 7    0.47544
# 8    9.09595
# 9   47.75395
# 10  52.94390
# 11  51.25347
# 12   0.10145
# 13  -5.81362
# 14  85.54556
# 15 402.97861
# 16 382.67372
# 17 359.47940
# 18  -0.02125
# 19   0.04075
# 20   0.10111
# 21   0.13992
# 22   0.06850
# 23   0.07834
# 24  -1.23258
# 25   4.09043
# 26   1.71510
# 27  44.35261
# 28  66.80650
# 29  79.13240
# 30  -1.90001
# 31  14.97774
# 32  21.51305
# 33  33.19437
# 34  35.60430
# 35  47.94560
# 36  -0.66279
# 37  -1.84070
# 38   6.22452
# 39 170.04952
# 40 283.43666
# 41 327.80132
# 42  -0.12807
# 43  -5.23153
# 44  26.71675
# 45 258.64293
# 46 243.69137
# 47 272.73704
# 48  -0.01004
# 49  -0.00245
# 50   0.00447
# 51   0.00977
# 52  -0.00729
# 53  -0.00135
# 54   0.81213
# 55  70.30724
# 56  93.26607
# 57 129.60946
# 58 144.36355
# 59 154.10317
# 60  -0.39707
# 61   0.30836
# 62  20.26088
# 63 116.60187
# 64  99.72595
# ...

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#       values
# 0   -0.08304
# 1   -0.07343
# 2    3.37981
# 3   38.63855
# 4   55.25072
# 5   67.55011
# 6    0.02428
# 7    0.47544
# 8    9.09595
# 9   47.75395
# 10  52.94390
# 11  51.25347
# 12   0.10145
# 13  -5.81362
# 14  85.54556
# 15 402.97861
# 16 382.67372
# 17 359.47940
# 18  -0.02125
# 19   0.04075
# 20   0.10111
# 21   0.13992
# 22   0.06850
# 23   0.07834
# 24  -1.23258
# 25   4.09043
# 26   1.71510
# 27  44.35261
# 28  66.80650
# 29  79.13240
# 30  -1.90001
# 31  14.97774
# 32  21.51305
# 33  33.19437
# 34  35.60430
# 35  47.94560
# 36  -0.66279
# 37  -1.84070
# 38   6.22452
# 39 170.04952
# 40 283.43666
# 41 327.80132
# 42  -0.12807
# 43  -5.23153
# 44  26.71675
# 45 258.64293
# 46 243.69137
# 47 272.73704
# 48  -0.01004
# 49  -0.00245
# 50   0.00447
# 51   0.00977
# 52  -0.00729
# 53  -0.00135
# 54   0.81213
# 55  70.30724
# 56  93.26607
# 57 129.60946
# 58 144.36355
# 59 154.10317
# 60  -0.39707
# 61   0.30836
# 62  20.26088
# 63 116.60187
# 64  99.72595
# ...

# %%
#df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
#df7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import pandas as pd

# Example DataFrame
data = {
    'percent_change': [24, 7, 30, 60, 90],
    'values': [100, 200, 300, 400, 500],
    'name': ['A', 'B', 'C', 'D', 'E']
}

df7 = pd.DataFrame(data)

# Create the plot
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#        name  quote.USD.price                  timestamp
# 0   Bitcoin      95949.58396 2024-12-03 20:09:16.421808
# 15  Bitcoin      95949.58396                        NaT

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
